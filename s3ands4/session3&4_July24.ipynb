# %% [markdown]
# !pip install pyforest

# %%
import pyforest
import scipy.stats as st

# %%
df= sns.load_dataset('tips')

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# sns.get_dataset_names()

# %% [markdown]
# 1. what is the % of male and female transactions?
# 2. Which day the transactions are more and less
# 3. whether dinner or lunch giving more revenue?
# 4. what is the % of smoking transactions?

# %%
df.sex.value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
mydf=sns.load_dataset('tips')
mydf.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
mydf.sex.value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
round(mydf.sex.value_counts(normalize=True)*100,0)
# Out:
# sex
# Male      64.0
# Female    36.0
# Name: proportion, dtype: float64

# %%
round(df.sex.value_counts(normalize=True)*100,0)
# Out:
# sex
# Male      64.0
# Female    36.0
# Name: proportion, dtype: float64

# %%
sns.countplot(x=mydf.sex)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x=df.sex)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
df['size'].sum()
# Out:
# 627

# %%
mydf['size'].sum()
# Out:
# 627

# %%
df.groupby('time')['total_bill'].sum()
# Out:
# C:\Users\malli\AppData\Local\Temp\ipykernel_31884\3868659607.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('time')['total_bill'].sum()
# time
# Lunch     1167.47
# Dinner    3660.30
# Name: total_bill, dtype: float64

# %%
mydf.groupby('time')['total_bill'].sum()
# Out:
# C:\Users\Chidi\AppData\Local\Temp\ipykernel_5744\3258652153.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mydf.groupby('time')['total_bill'].sum()
# time
# Lunch     1167.47
# Dinner    3660.30
# Name: total_bill, dtype: float64

# %%
df.total_bill.describe()
# Out:
# count    244.000000
# mean      19.785943
# std        8.902412
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810000
# Name: total_bill, dtype: float64

# %%
mydf.total_bill.describe()
# Out:
# count    244.000000
# mean      19.785943
# std        8.902412
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810000
# Name: total_bill, dtype: float64

# %%
iqr= 24.1275-13.3475
iqr
# Out:
# 10.780000000000001

# %%
import scipy.stats as st
stats.stats.iqr(mydf.total_bill)
# Out:
# C:\Users\Chidi\AppData\Local\Temp\ipykernel_5744\3313961993.py:2: DeprecationWarning: Please import `iqr` from the `scipy.stats` namespace; the `scipy.stats.stats` namespace is deprecated and will be removed in SciPy 2.0.0.
#   stats.stats.iqr(mydf.total_bill)
# 10.779999999999998

# %%
df.total_bill.quantile(0.75)-df.total_bill.quantile(0.25)
# Out:
# 10.779999999999998

# %%
mydf.total_bill.quantile(0.75) - mydf.total_bill.quantile(0.25)
# Out:
# 10.779999999999998

# %%
import scipy

# %%
scipy.stats.iqr(df.total_bill)
# Out:
# 10.779999999999998

# %%
iqr=mydf.total_bill.quantile(0.75) - mydf.total_bill.quantile(0.25)
lb= mydf.total_bill.quantile(0.25)-1.5*iqr
lb
# Out:
# -2.8224999999999945

# %%
lowerbound=mydf.total_bill.quantile(0.25) -1.5 *iqr
lowerbound
upperbound = mydf.total_bill.quantile(0.75) + 1.5 *iqr
upperbound
# Out:
# 40.29749999999999

# %%
ub= df.total_bill.quantile(0.75)+1.5*iqr
ub
# Out:
# 40.2975

# %% [markdown]
# !pip install plotly

# %%
px.box(df.total_bill)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 px.box(df.total_bill)
#
# NameError: name 'df' is not defined

# %%
df.total_bill.mean()
# Out:
# 19.78594262295082

# %%
sns.boxplot(mydf.total_bill)
# Out:
# <Axes: ylabel='total_bill'>

# %%
df.total_bill.median()
# Out:
# 17.795

# %%
mydf.total_bill.median()
# Out:
# 17.795

# %%
df.total_bill.mode()
# Out:
# 0    13.42
# Name: total_bill, dtype: float64

# %%
mydf.total_bill.mode()
# Out:
# 0    13.42
# Name: total_bill, dtype: float64

# %% [markdown]
# # Binomial Distribution

# %%
n=3
p=0.5
# P(x=0)=? to P(x=3)=?

# %%
import numpy as np
n=3
p=0.5
#p(x=0) to p(x=3)=?
x=np.arange(0,4)
print("probability mass function ",st.binom.pmf(x,n,p))
print("cummulative distribution function",st.binom.cdf(x,n,p))
print("survival function",st.binom.sf(x-1,n,p))
print("cummulativedistributive function + survival fucntion",(st.binom.cdf(x,n,p)+ st.binom.sf(x,n,p)))
# Out:
# probability mass function  [0.125 0.375 0.375 0.125]
# cummulative distribution function [0.125 0.5   0.875 1.   ]
# survival function [1.    0.875 0.5   0.125]
# cummulativedistributive function + survival fucntion [1. 1. 1. 1.]

# %%
st.binom.pmf(0,3,0.5)
# Out:
# 0.12499999999999999

# %%
x= np.arange(0,4)

# %%
st.binom.pmf(x,3,0.5)
# Out:
# array([0.125, 0.375, 0.375, 0.125])

# %%
st.binom.cdf(x,3,0.5)
# Out:
# array([0.125, 0.5  , 0.875, 1.   ])

# %%
st.binom.sf(x-1,3,0.5)
# Out:
# array([1.   , 0.875, 0.5  , 0.125])

# %%
st.binom.cdf(1,3,0.5)+st.binom.sf(1,3,0.5)
# Out:
# 1.0

# %%
st.binom.sf(-1,3,0.5)
# Out:
# 1.0

# %%
st.binom.cdf(1,3,0.5)
# Out:
# 0.5

# %%
st.binom.stats(n,p)
# Out:
# (1.5, 0.75)

# %%
st.binom.stats(n,p)
# Out:
# (1.5, 0.75)

# %% [raw]
# p= prob of purchase =0.3
# n=40
# P(x=12)=?

# %%
x=np.arange(0,13)
n=40
p=0.3
st.binom.pmf(12,n,p)
# Out:
# 0.13657382060056145

# %%
n=40
p=0.3

# %%
## P(x=12)=?
st.binom.pmf(12,n,p)
# Out:
# 0.13657382060056145

# %%
## what is the prob of min 15 customers purchase the product?
x= np.arange(15,41)
st.binom.pmf(x,n,p).sum()
# Out:
# 0.19255175473517608

# %%
x=np.arange(15,41)
st.binom.pmf(x,n,p).sum()
# Out:
# 0.19255175473517608

# %%
1-st.binom.cdf(14,n,p)
# Out:
# 0.1925517547351756

# %%
1-st.binom.cdf(14,n,p)
# Out:
# 0.1925517547351756

# %%
st.binom.sf(14,n,p)
# Out:
# 0.19255175473517566

# %%
st.binom.sf(14,n,p)
# Out:
# 0.19255175473517566

# %% [markdown]
# what is the prob of 15-20 customers purcahse the product?

# %%
st.binom.cdf(20,n,p)-st.binom.cdf(14,n,p)
# Out:
# 0.190132394838042

# %%
st.binom.cdf(20,n,p) - st.binom.cdf(14,n,p)
# Out:
# 0.190132394838042

# %%
st.binom.cdf(20,n,p) - st.binom.cdf(14,n,p)
# Out:
# 0.190132394838042

# %%
st.binom.cdf(20,40,3/10)-st.binom.cdf(14,40,3/10)
# Out:
# 0.190132394838042

# %%
st.binom.cdf(20,40,0.3) - st.binom.cdf(14,40,0.3)
# Out:
# 0.190132394838042

# %%
x= np.arange(0,41)
pmf= st.binom.pmf(x,40,0.5)
plt.bar(x,pmf)
plt.show()

# %%
n=40
p=0.3
x=np.arange(0,41)
pmf = st.binom.pmf(x,n,p)
plt.bar(x,pmf)
cdf=st.binom.cdf(x,n,p)
plt.bar(x,cdf)
sf=st.binom.sf(x,n,p)
plt.bar(x,sf)
plt.show()

# %%
cdf= st.binom.cdf(x, n,p)
plt.bar(x,cdf)
# Out:
# <BarContainer object of 41 artists>

# %% [markdown]
# # Normal Distribution

# %% [raw]
# mean age= 35
# sd of age= 5
# i) P(X>=40)=?
# ii) P(30<=x<=50)=?
# iii) P(X<=40)=?

# %%
mu= 35
sigma=5

# %%
mu=35
sigma=5

# %%
# P(x>40)=?
st.norm.sf(40,mu,sigma)
# Out:
# 0.15865525393145707

# %%
st.norm.sf(40,mu,sigma)
# Out:
# 0.15865525393145707

# %%
40*0.15865525393145707
# Out:
# 6.346210157258283

# %%
40*0.15865525393145707
# Out:
# 6.346210157258283

# %%
mu=35
sigma=5
# P(x>40)=?
print("P(x>40)",st.norm.sf(40,mu,sigma))
# P(30<=X<=50) 
print("P(30<=X<=50) using cdf",st.norm.cdf(50,mu,sigma) - st.norm.cdf(30,mu,sigma))
print(" P(30<=X<=50) using sf",st.norm.sf(30,mu,sigma) - st.norm.sf(50,mu,sigma))
print("using cdf and sf together",1-(st.norm.cdf(30,mu,sigma) + st.norm.sf(50,mu,sigma) ))
# P(25<=X<=45)
print("\n P(25<=X<=45) using cdf",st.norm.cdf(45,mu,sigma) - st.norm.cdf(25,mu,sigma))
print("\n P(25<=X<=45) using sf",st.norm.sf(25,mu,sigma) - st.norm.sf(45,mu,sigma))
print("\n P(25<=X<=45) using cdf and sf", 1 - (st.norm.cdf(25,mu,sigma) + st.norm.sf(45,mu,sigma)))
# Out:
# P(x>40) 0.15865525393145707
# P(30<=X<=50) using cdf 0.8399948480369128
#  P(30<=X<=50) using sf 0.8399948480369128
# using cdf and sf together 0.8399948480369128
#
#  P(25<=X<=45) using cdf 0.9544997361036416
#
#  P(25<=X<=45) using sf 0.9544997361036416
#
#  P(25<=X<=45) using cdf and sf 0.9544997361036416

# %%
40 * 0.15865525393145707
# Out:
# 6.346210157258283

# %%
# P(30<=X<=50)  ## using cdf function
st.norm.cdf(50,mu,sigma)-st.norm.cdf(30,mu,sigma)
# Out:
# 0.8399948480369128

# %%
## using sf function
st.norm.sf(30,mu,sigma)-st.norm.sf(50,mu,sigma)
# Out:
# 0.8399948480369128

# %%
st.norm.sf(30,mu,sigma) - st.norm.sf(50,mu,sigma)
# Out:
# 0.8399948480369128

# %%
# using both cdf and sf
1- (st.norm.cdf(30,mu,sigma)+st.norm.sf(50,mu,sigma))
# Out:
# 0.8399948480369128

# %%
1-(st.norm.cdf(30,mu,sigma)+st.norm.sf(50,mu,sigma))
# Out:
# 0.8399948480369128

# %%
x1= np.arange(0,100, 0.01)
mu=35
sigma=5
pdf= st.norm.pdf(x1, mu,sigma)
plt.plot(x1, pdf)

# %%
normal_x=np.arange(0,100,0.2)
pdf=st.norm.pdf(normal_x,mu,sigma)
plt.plot(normal_x,pdf)

# %%
cdf1= st.norm.cdf(x1,mu,sigma)
plt.plot(x1,cdf1)

# %%
normal_cdf=st.norm.cdf(normal_x,mu,sigma)
plt.plot(normal_x,normal_cdf)

# %%
# P(30<=X<=40)  ## using cdf function : mu +-1 sigma
st.norm.cdf(40,mu,sigma)-st.norm.cdf(30,mu,sigma)
# Out:
# 0.6826894921370859

# %%
st.norm.cdf(40,mu,sigma) - st.norm.cdf(30,mu,sigma)
# Out:
# 0.6826894921370859

# %%
# P(25<=X<=45)  ## using cdf function : mu +-2 sigma
st.norm.cdf(45,mu,sigma)-st.norm.cdf(25,mu,sigma)
# Out:
# 0.9544997361036416

# %%
st.norm.sf(25,mu,sigma) - st.norm.sf(45,mu,sigma)
# Out:
# 0.9544997361036416

# %%
# P(20<=X<=50)  ## using cdf function : mu +-3 sigma
st.norm.cdf(50,mu,sigma)-st.norm.cdf(20,mu,sigma)
# Out:
# 0.9973002039367398

# %%
st.norm.cdf(50,mu,sigma) - st.norm.cdf(20,mu,sigma)
# Out:
# 0.9973002039367398

# %%
st.norm.sf(20,mu,sigma) - st.norm.sf(50,mu,sigma)
# Out:
# 0.9973002039367398

# %%
1 - ( st.norm.cdf(20,mu,sigma) + st.norm.sf(50,mu,sigma))
# Out:
# 0.9973002039367398

# %% [markdown]
# Standard Normal Distribution

# %%
# P(-1<=Z<=1)  ## using cdf function : Z = +-1
st.norm.cdf(1,0,1)-st.norm.cdf(-1)
# Out:
# 0.6826894921370859

# %%
print("standard normal distribution")

print("p(-1<=Z<=1)",st.norm.cdf(1)-st.norm.cdf(-1))
print("p(-2<=Z<=2)",st.norm.cdf(2)-st.norm.cdf(-2))
print("p(-3<=Z<=3)",st.norm.cdf(3)-st.norm.cdf(-3))
print("p(-4<=Z<=4)",st.norm.cdf(4)- st.norm.cdf(-4))
# Out:
# standard normal distribution
# p(-1<=Z<=1) 0.6826894921370859
# p(-2<=Z<=2) 0.9544997361036416
# p(-3<=Z<=3) 0.9973002039367398
# p(-4<=Z<=4) 0.9999366575163338
# p(-4.65 <= Z <=4.65 0.0

# %%
# P(-2<=Z<=2)  ## using cdf function : Z = +-2
st.norm.cdf(2)-st.norm.cdf(-2)
# Out:
# 0.9544997361036416

# %%
# P(-3<=Z<=3)  ## using cdf function : Z = +-3
st.norm.cdf(3)-st.norm.cdf(-3)
# Out:
# 0.9973002039367398

# %%
# P(-4.65<=Z<=4.65)  ## using cdf function : Z = +-4.65
st.norm.cdf(4.65)-st.norm.cdf(-4.65)
# Out:
# 0.9999966806497114

# %%
(1-0.9999966806497114)*1000000
# Out:
# 3.3193502886330606

# %%
## what is the min  age of learners where 60% of them are 
## having that min age?
sf=0.6
mu=35
sigma=5
st.norm.isf(sf, mu,sigma)
# Out:
# 33.733264484321005

# %%
mu=35
sf=0.6
sigma=5
st.norm.isf(sf,mu,sigma)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 sf=0.6
#       3 sigma=5
# ----> 4 st.norm.isf(sf,mu,sigma)
#
# NameError: name 'st' is not defined

# %%
sf=0.6
mu=35
sigma=5
st.norm.isf(sf,mu,sigma)
# Out:
# 33.733264484321005

# %%
## what is the max age of learners where 75% of them are 
## having that max age?
cdf=0.75
mu=35
sigma=5
st.norm.ppf(cdf, mu,sigma)
# Out:
# 38.37244875098041

# %%
cdf=0.75
mu=35
sigma=5
st.norm.ppf(cdf,mu,sigma)
# Out:
# 38.37244875098041

# %% [markdown]
# # Simple Random Sampling

# %% [markdown]
# #### 1.  An ice-cream manufacturer wants to study the sales of ice-creams to decide the production policies of the company. He collects the data for the number of ice-creams sold in a month from the 30 franchise. Randomly select the sales of 10 franchise for the study.
# data = [21, 93, 62, 76, 73, 20, 56, 95, 41, 36, 38, 13, 80, 88, 34, 18, 40, 11, 25, 29, 61, 23, 82, 10, 92, 69, 60, 87, 14, 91]

# %%
import random

# %%
import random

# %%
data = [21, 93, 62, 76, 73, 20, 56, 95, 41, 36, 38, 13, 80, 88, 34, 18, 40, 11, 25, 29, 61, 23, 82, 10, 92, 69, 60, 87, 14, 91]

# %%
mdata=[21, 93, 62, 76, 73, 20, 56, 95, 41, 36, 38, 13, 80, 88, 34, 18, 40, 11, 25, 29, 61, 23, 82, 10, 92, 69, 60, 87, 14, 91]

# %%
np.random.seed(1000000)
random.seed(1000)

# %%
random.seed(100)

# %%
## SRS -without replacement
sample= random.sample(data, k=10)
sample
# Out:
# [92, 88, 23, 91, 76, 80, 13, 62, 34, 20]

# %%
msample=random.sample(mdata,k=10)
msample
# Out:
# [56, 38, 95, 36, 92, 91, 20, 73, 69, 13]

# %%
## collect sample of 50 data points:
## SRS with replacement:
sample_withreplacement= random.choices(data, k=10)
sample_withreplacement
# Out:
# [40, 91, 76, 61, 38, 34, 56, 29, 56, 88]

# %%
msample_with_replacement=random.choices(mdata,k=10)
msample_with_replacement
# Out:
# [20, 25, 73, 69, 73, 20, 21, 29, 91, 10]

# %% [markdown]
# # Stratified Random Sampling

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
df= sns.load_dataset('tips')

# %%
mydf=sns.load_dataset('tips')
mydf.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
df.time.value_counts(normalize=True)*100
# Out:
# time
# Dinner    72.131148
# Lunch     27.868852
# Name: proportion, dtype: float64

# %%
mydf.time.value_counts(normalize=True) * 100
# Out:
# time
# Dinner    72.131148
# Lunch     27.868852
# Name: proportion, dtype: float64

# %%
x=df.drop('time', axis=1)
x.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 x=df.drop('time', axis=1)
#       2 x.head(2)
#
# NameError: name 'df' is not defined

# %%
x=mydf.drop('time',axis=1)
x.head(2)
# Out:
#    total_bill   tip     sex smoker  day  size
# 0       16.99  1.01  Female     No  Sun     2
# 1       10.34  1.66    Male     No  Sun     3

# %%
y= df.time

# %%
y=mydf.time

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=0.2, stratify=df.time)

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2 , stratify=mydf.time)

# %%
y_train.value_counts(normalize=True)
# Out:
# time
# Dinner    0.723077
# Lunch     0.276923
# Name: proportion, dtype: float64

# %%
y_train.value_counts(normalize=True)
# Out:
# time
# Dinner    0.723077
# Lunch     0.276923
# Name: proportion, dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
# time
# Dinner    0.714286
# Lunch     0.285714
# Name: proportion, dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
# time
# Dinner    0.714286
# Lunch     0.285714
# Name: proportion, dtype: float64

# %%
print(y_test.shape, y_train.shape)
# Out:
# (49,) (195,)

# %%
print(y_test.shape , y_train.shape)
# Out:
# (49,) (195,)

# %%
import scipy.stats as st

# %%
import scipy.stats as st

# %%
population1= st.norm.rvs(10,0.5, 1000)
population1

# %%
mpopulation1 = st.norm.rvs(10,0.5,1000)
len(mpopulation1)
# Out:
# 1000

# %%
len(population1)
# Out:
# 100000

# %%
sns.distplot(population1)
# Out:
# C:\Users\malli\AppData\Local\Temp\ipykernel_31884\4265792527.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: ylabel='Density'>

# %%
sns.displot(mpopulation1)

# %%
population2= st.skewnorm.rvs(-10, 0.5, size=100000)
population2
# Out:
# array([-0.09250379,  0.04653857,  0.15006428, ...,  0.32663197,
#        -0.15087463, -0.13075175])

# %%
mpopulation2=st.skewnorm.rvs(-10,0.5,size=1000)
mpopulation2

# %%
len(population2)
# Out:
# 100000

# %%
len(mpopulation2)
# Out:
# 1000

# %%
sns.distplot(population2)
# Out:
# C:\Users\malli\AppData\Local\Temp\ipykernel_31884\2738959746.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: ylabel='Density'>

# %%
sns.displot(mpopulation2)

# %%
population3= st.skewnorm.rvs(10, 0.5, size=100000)
len(population3)
# Out:
# 100000

# %%
mpopulation3 = st.skewnorm.rvs(10,0.5,size=1000)

# %%
sns.distplot(population3)
# Out:
# C:\Users\malli\AppData\Local\Temp\ipykernel_31884\2823363394.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: ylabel='Density'>

# %%
sns.displot(mpopulation3)

# %%
smeans_2=[np.mean(random.sample(list(population2), k=50)) for i in range (0,70)]

# %%
ms_means2= [np.mean(random.sample(list(mpopulation2),k=50))  for i in range (0,70)]

# %%
len(smeans_2)
# Out:
# 70

# %%
len(ms_means2)
# Out:
# 70

# %%
sns.distplot(smeans_2)
# Out:
# C:\Users\malli\AppData\Local\Temp\ipykernel_31884\1675015582.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: ylabel='Density'>

# %%
sns.displot(ms_means2)

# %%
mu2= np.mean(population2)
mu2
# Out:
# -0.2916599338377218

# %%
np.mean(smeans_2)
# Out:
# -0.28165644653935623

# %%
std_error= np.std(smeans_2)
std_error
# Out:
# 0.08804886778969948

# %%
stderr=np.std(ms_means2)
stderr
# Out:
# 0.08489448820357531

# %%
np.std(population2)/np.sqrt(50)
# Out:
# 0.08553098709579902

# %%
np.std(mpopulation2) / np.sqrt(50)
# Out:
# 0.08699001541299702

# %%
smeans_3=[np.mean(random.sample(list(population3), k=50)) for i in range (0,70)]

# %%
ms_means3=[np.mean (random.sample(list(mpopulation3),k=50))  for i in range(70)]

# %%
sns.distplot(smeans_3)
# Out:
# C:\Users\malli\AppData\Local\Temp\ipykernel_31884\2503300424.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: ylabel='Density'>

# %%
len(ms_means3)
# Out:
# 70

# %%
sns.distplot(ms_means3)
# Out:
# C:\Users\Chidi\AppData\Local\Temp\ipykernel_13992\2302537833.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ms_means3)
# <Axes: ylabel='Density'>

# %%
mu3=np.mean(population3)
mean_smeans= np.mean(smeans_3)
print(mu3, mean_smeans)
# Out:
# 1.2936164865508892 1.281044918585952

# %%
mu3=np.mean(mpopulation3)
mean_ms_means3= np.mean(ms_means3)
print(mu3,mean_ms_means3)
# Out:
# 1.2983335543387273 1.3018184887318895

# %%
std_error=np.std(smeans_3)
sigma_byn= np.std(population3)/np.sqrt(50)
print(std_error, sigma_byn)
# Out:
# 0.07387360205707832 0.08606743332235967

# %%
stderr3=np.std(ms_means3)
sigma_byn=np.std(mpopulation3 ) / np.sqrt(50)
print(stderr3,sigma_byn)
# Out:
# 0.09140610020952063 0.08679538306030975
